# %%
from IPython.core.display import HTML
HTML("""
<style>

div.cell { /* Tunes the space between cells */
margin-top:1em;
margin-bottom:1em;
}

div.text_cell_render h1 { /* Main titles bigger, centered */
font-size: 2.2em;
line-height:1.4em;
text-align:center;
}

div.text_cell_render h2 { /*  Parts names nearer from text */
margin-bottom: -0.4em;
}


div.text_cell_render { /* Customize text cells */
font-family: 'Times New Roman';
font-size:1.5em;
line-height:1.4em;
padding-left:3em;
padding-right:3em;
}
</style>
""")
# Out:
# <style>
#
# div.cell { /* Tunes the space between cells */
# margin-top:1em;
# margin-bottom:1em;
# }
#
# div.text_cell_render h1 { /* Main titles bigger, centered */
# font-size: 2.2em;
# line-height:1.4em;
# text-align:center;
# }
#
# div.text_cell_render h2 { /*  Parts names nearer from text */
# margin-bottom: -0.4em;
# }
#
#
# div.text_cell_render { /* Customize text cells */
# font-family: 'Times New Roman';
# font-size:1.5em;
# line-height:1.4em;
# padding-left:3em;
# padding-right:3em;
# }
# </style>

# %% [markdown]
# ## ![](https://dg9f2badvburd.cloudfront.net/media/1912pike/2016/06/28/five-drinks-hero-1.jpg)

# %% [markdown]
# ## Do you know how many Starbucks in the world? <BR>Do you know how many countries have starbucks ?<BR>Do you know how many cities have starbucks ?

# %% [markdown]
# There are 25,584 Starbucks stores in the world. <Br>There are 73 Countries have Starbucks stores. <Br>There are 5,464 Cities have Starbucks stores.

# %% [markdown]
# # Main Insights :
# + U.S.A, China, Canada, Japen and Korea are Top 5 Countries with most Starbucks stores. Around 60% of the stores in the North America and 20% in the East Asia market.
# + Shanghai, Seoul, Bejing , New York, London are Top 5 Cities with most Starbucks stores. Shanghai has double amount of stores compared to New York.
# + China is the Starbucks'second largest market and this analysis shows the market still has strong potential for further expansion.
# + In majority of East Asia market, Starbucks has joint venture with other companies.

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %% [markdown]
# ## Data Preparation

# %%
data = pd.read_csv('directory.csv',encoding='ISO-8859-1')
data.head()
# Out:
#        Brand  Store_Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# ...

# %%
data.shape
# Out:
# (25600, 13)

# %%
# check 
chk1= data.duplicated(subset=['Store_Number']).sum()
chk1
# Out:
# 1

# %%
data.drop_duplicates(subset=['Store_Number'],keep='first', inplace=True)

# %%
data.isnull().sum()
# Out:
# Brand                0
# Store_Number         0
# Store Name           0
# Ownership Type       0
# Street Address       2
# City                15
# State/Province       0
# Country              0
# Postcode          1522
# Phone Number      6860
# Timezone             0
# Longitude            1
# Latitude             1
# dtype: int64

# %%
# Remove missing values 
data1= data.dropna(subset=['City'])
data1.isnull().sum()
# Out:
# Brand                0
# Store_Number         0
# Store Name           0
# Ownership Type       0
# Street Address       2
# City                 0
# State/Province       0
# Country              0
# Postcode          1507
# Phone Number      6860
# Timezone             0
# Longitude            1
# Latitude             1
# dtype: int64

# %%
data1.shape
# Out:
# (25584, 13)

# %% [markdown]
# ## Starbucks Stores Worldwide

# %%
plt.figure(figsize=(10, 10))
m = Basemap(projection='ortho', resolution=None, lat_0=50, lon_0=-100)
m.bluemarble(scale=0.5);

x, y = m(list(data1["Longitude"].astype(float)), list(data1["Latitude"].astype(float)))
m.plot(x, y, 'bo', markersize = 5, alpha = 0.6, color = "green")

plt.title('Starbucks Stores Across the World')
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3296: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3305: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
# ...

# %%
plt.figure(figsize=(15,20))
m = Basemap(projection = 'mill', llcrnrlat = -80, urcrnrlat = 80, llcrnrlon = -180, urcrnrlon = 180, resolution = 'h')
m.drawcoastlines()

m.drawmapboundary(fill_color='white')

x, y = m(list(data1["Longitude"].astype(float)), list(data1["Latitude"].astype(float)))
m.plot(x, y, 'bo', markersize = 5, alpha = 0.6, color = "green")

plt.title('Starbucks Stores Across the World')
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1698: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
data1.Country.describe()
# Out:
# count     25584
# unique       73
# top          US
# freq      13608
# Name: Country, dtype: object

# %%
print ('There are 25,584 Starbucks stores in the world')
print ('There are 73 Countries have Starbucks stores')
# Out:
# There are 25,584 Starbucks stores in the world
# There are 73 Countries have Starbucks stores

# %%
data1.City.describe()
# Out:
# count        25584
# unique        5464
# top       shanghai
# freq           551
# Name: City, dtype: object

# %%
print ('There are 5,464 cities have Starbucks stores')
# Out:
# There are 5,464 cities have Starbucks stores

# %% [markdown]
# # Top 10 Countries

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(111)
ax.set(title = "Top 10 Countries with Most Number of Starbucks Stores")
data1.Country.value_counts().head(10).plot(kind="bar", color = "green")

p=data.Country.value_counts()/len(data.Country)
pcts = (data1.Country.value_counts(normalize=True) * 100).apply(lambda x: '{:.2f}%'.format(x))

for i, p in enumerate(ax.patches):
    ax.annotate(pcts[i], (p.get_x(), p.get_height() * 1.01))
       
plt.show()

# %% [markdown]
# # Top 10 Cities with most number of Starbucks Stores

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(111)
ax.set(title = "Top 10 Cities with most number of Starbucks Stores")
data1.City.value_counts().head(10).plot(kind="bar",color = "green")

p=data.City.value_counts()/len(data.City)
pcts = (data1.City.value_counts(normalize=True) * 100).apply(lambda x: '{:.2f}%'.format(x))

for i, p in enumerate(ax.patches):
    ax.annotate(pcts[i], (p.get_x(), p.get_height() * 1.01))

plt.show()

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(111)
usa_states = data1[data1['Country'] == 'US']
ax.set(title="What are the Top 10 States in USA with most number of stores?")
usa_states['State/Province'].value_counts().head(10).plot(kind="bar",color = "green")

p=usa_states['State/Province'].value_counts()/len(data1.City)
pcts = (usa_states['State/Province'].value_counts(normalize=True) * 100).apply(lambda x: '{:.2f}%'.format(x))
pcts = (usa_states.City.value_counts(normalize=True) * 100).apply(lambda x: '{:.2f}%'.format(x))

for i, p in enumerate(ax.patches):
    ax.annotate(pcts[i], (p.get_x(), p.get_height() * 1.01))

plt.show()

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(111)
usa_states = data1[data1['Country'] == 'US']
ax.set(title="What are the Top 10 City with most number of stores in the USA?")
usa_states.City.value_counts().head(10).plot(kind="bar",color = "green")

p=usa_states.City.value_counts()/len(data1.City)
pcts = (usa_states.City.value_counts(normalize=True) * 100).apply(lambda x: '{:.2f}%'.format(x))

for i, p in enumerate(ax.patches):
    ax.annotate(pcts[i], (p.get_x(), p.get_height() * 1.01))    

plt.show()

# %%
# %matplotlib inline
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
ax.set(title = "Who owns the stores?")
plt1=data1['Ownership Type'].value_counts().plot(kind="pie",autopct='%1.1f%%',startangle=270, fontsize=10, labeldistance=0.6, pctdistance=0.4,colors=['forestgreen', 'orange','gray','red'])
plt1=plt1.axes.get_yaxis().set_ticklabels([])
plt1
# Out:
# []

# %%
print ('46% of the stores are company owned')
print ('Less than 2% are franchised stores')
# Out:
# 46% of the stores are company owned
# Less than 2% are franchised stores

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
ax.set(title = "Who owns the stores in USA?")
usa_states['Ownership Type'].value_counts().plot(kind="pie",autopct='%1.1f%%',startangle=270, fontsize=10, labeldistance=0.5, pctdistance=0.3,colors=['forestgreen', 'orange'])
plt.show()

# %%
import pylab 
CN = data1[data1['Country'] == 'CN']
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
ax.set(title = "Who owns the stores in CN?")
CN['Ownership Type'].value_counts().plot(kind="pie",autopct='%1.1f%%', startangle=270, fontsize=10, labeldistance=0.8, pctdistance=0.4,colors=['forestgreen', 'orange', 'gray'])
plt.show()

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(111)
JV = data1[data1['Ownership Type'] == 'Joint Venture']
ax = fig.add_subplot(111)
ax.set(title = "Top 5 countries having Starbuck by Joint Venture")
JV['Country'].value_counts().head(5).plot(kind="bar",color = "green")
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
Franchise = data1[data1['Ownership Type'] == 'Franchise']
Franchise['Country'].value_counts()
# Out:
# GB    302
# FR     15
# Name: Country, dtype: int64

# %%
print ('In the U.S.A, 40% of the stores are licensed, in China 45% stores are joint venture')
print('In China 45% stores are joint venture and 49% are owned by company' )
print ('Starbucks has joint venture with other companies in major East Asia market.')
# Out:
# In the U.S.A, 40% of the stores are licensed, in China 45% stores are joint venture
# In China 45% stores are joint venture and 49% are owned by company
# Starbucks has joint venture with other companies in major East Asia market.
